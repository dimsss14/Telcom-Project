# %%
import pandas as pd
import numpy as np

main = pd.read_excel(r'/Users/mac/Downloads/main.xlsx')
second = pd.read_excel(r'/Users/mac/Downloads/second.xlsx')

# %%
main.columns = main.columns.str.replace(' ', '', regex=False)
second.columns = second.columns.str.replace(' ', '', regex=False)

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           20 non-null     object
#  1   Customer_Name  20 non-null     object
#  2   Product_Code   20 non-null     object
#  3   Description    20 non-null     object
#  4   Quantity       20 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 932.0+ bytes

# %%
main['Date'] = pd.to_datetime(main['Date'])
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           20 non-null     datetime64[ns]
#  1   Customer_Name  20 non-null     object
#  2   Product_Code   20 non-null     object
#  3   Description    20 non-null     object
#  4   Quantity       20 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 932.0+ bytes
# /var/folders/fr/l2l2gyx54tx7qk821pfl12w40000gn/T/ipykernel_2004/1958505778.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   main['Date'] = pd.to_datetime(main['Date'])

# %%
main
# Out:
#          Date                          Customer_Name  Product_Code  \
# 0  2022-12-28  PERSEROAN TERBATAS ALU AKSARA PRATAMA  8.00691.0250
# 1  2022-12-22             BISI INTERNATIONAL TBK, PT  8.22343.0100
# 2  2022-12-28                  SARIFEED INDOJAYA, PT  1.00063.1000
# 3  2022-07-12         BATARA ELOK SEMESTA TERPADU,PT  1.00063.2511
# 4  2022-12-14                       GELORA DJAJA, PT  1.00063.2500
# 5  2022-12-29     INDOFOOD CBP SUKSES MAKMUR Tbk, PT  1.00063.2511
# 6  2022-12-13        JAPFA COMFEED INDONESIA TBK, PT  1.00063.2500
# 7  2022-12-21               MAXXI AGRI INDONESIA, PT  1.00063.2500
# 8  2022-12-27           SALIM IVOMAS PRATAMA TBK, PT  1.00063.2500
# 9  2022-08-12                    SIANTAR TOP Tbk, PT  1.00063.2511
# 10 2022-12-26                           ESSENTRA, PT  1.00030.4000
# 11 2022-12-15                  HEXA TUNGGAL JAYA, PT  1.00030.4000
# 12 2022-12-23               MAXXI AGRI INDONESIA, PT  1.00030.4000
# ...

# %%
harga_jual = main.merge(second, on='Product_Code')
harga_jual
# Out:
#          Date                          Customer_Name  Product_Code  \
# 0  2022-12-28  PERSEROAN TERBATAS ALU AKSARA PRATAMA  8.00691.0250
# 1  2022-12-22             BISI INTERNATIONAL TBK, PT  8.22343.0100
# 2  2022-12-28                  SARIFEED INDOJAYA, PT  1.00063.1000
# 3  2022-07-12         BATARA ELOK SEMESTA TERPADU,PT  1.00063.2511
# 4  2022-12-29     INDOFOOD CBP SUKSES MAKMUR Tbk, PT  1.00063.2511
# 5  2022-08-12                    SIANTAR TOP Tbk, PT  1.00063.2511
# 6  2022-12-14                       GELORA DJAJA, PT  1.00063.2500
# 7  2022-12-13        JAPFA COMFEED INDONESIA TBK, PT  1.00063.2500
# 8  2022-12-21               MAXXI AGRI INDONESIA, PT  1.00063.2500
# 9  2022-12-27           SALIM IVOMAS PRATAMA TBK, PT  1.00063.2500
# 10 2022-12-26                           ESSENTRA, PT  1.00030.4000
# 11 2022-12-15                  HEXA TUNGGAL JAYA, PT  1.00030.4000
# 12 2022-12-23               MAXXI AGRI INDONESIA, PT  1.00030.4000
# ...

# %%
total_hargajual = harga_jual['Harga_Jual'].sum()
total_hargajual
# Out:
# 27385700
